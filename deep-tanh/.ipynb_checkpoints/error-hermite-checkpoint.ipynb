# %%
import numpy as np
import matplotlib.pyplot as plt
import func

# %%
# Goal: showing that high errors of g happen near 1 if g is computed by Hermite expansion
# cure: compute g by Gaussian integral

# %%
sig = lambda x: np.tanh(2*x)
mu1 = func.Ez( lambda x: x*sig(x) )
nu = func.Ez( lambda x: sig(x)**2 )
sig_n = lambda x: (sig(x)-mu1*x)/np.sqrt(nu - mu1**2) # normalized sig

g, _, _ = func.gg(sig_n, 25)
1-g(1)
# Out:
# /home/mnguyen/projects/minhtoan/deep-NN/unit_test/deep-tanh/func.py:10: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return quad(lambda x: f(x)*np.exp(-x**2/2)/np.sqrt(2*np.pi), -10, 10)[0]
# np.float64(0.0031983859526785174)

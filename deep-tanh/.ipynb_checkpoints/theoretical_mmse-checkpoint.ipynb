# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import AAA
from deep_tanh import *

# %%
# generate and save theoretical data
L = 1
q_init = np.ones(L)
alphas = np.concatenate((np.linspace(1.4*L, 1.8*L, 201), np.linspace(1.8*L, 5*L, 101)))
Delta = 0.1
results = np.array([quantities(q_init, alpha, Delta) for alpha in alphas]).T
np.savetxt(f'data/L_{L}.csv', results, delimiter=',')
